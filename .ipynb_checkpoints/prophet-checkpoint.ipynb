# %%
#https://facebook.github.io/prophet/docs/quick_start.html#python-api
import pandas as pd
from prophet import Prophet

# %%
df = pd.read_csv('avocado.csv')

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
ts = df.groupby('Date')['AveragePrice'].sum().reset_index()

# %%
ts.rename(columns={"Date": "ds", "AveragePrice": "y"}, inplace = True)

# %%
ts
# Out:
#             ds       y
# 0   2015-01-04  140.54
# 1   2015-01-11  148.03
# 2   2015-01-18  150.24
# 3   2015-01-25  150.89
# 4   2015-02-01  134.68
# ..         ...     ...
# 164 2018-02-25  146.84
# 165 2018-03-04  145.82
# 166 2018-03-11  144.19
# 167 2018-03-18  141.88
# 168 2018-03-25  145.46
#
# [169 rows x 2 columns]

# %%
m = Prophet()
m.fit(ts)
# Out:
# 22:15:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:15:17 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 529 2019-03-21
# 530 2019-03-22
# 531 2019-03-23
# 532 2019-03-24
# 533 2019-03-25

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 529 2019-03-21  138.869810  125.400606  151.762321
# 530 2019-03-22  139.083210  126.439530  151.818701
# 531 2019-03-23  139.332666  125.259073  151.365010
# 532 2019-03-24  139.615427  126.092103  152.037923
# 533 2019-03-25  139.927821  126.920425  152.827795

# %%
# Python
fig1 = m.plot(forecast)
# Out:
# c:\Users\topher\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\topher\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
# Python
fig2 = m.plot_components(forecast)
# Out:
# c:\Users\topher\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\topher\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\topher\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
# Python
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)
